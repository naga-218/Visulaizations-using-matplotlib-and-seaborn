# %%
import warnings
warnings.filterwarnings('ignore')

import seaborn as sns

# %%
sns.set_style()

df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.__version__
# Out:
# '0.10.0'

# %%
# pip install seaborn --upgrade

# C:\Users\naga\anaconda3\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
sns.distplot(df['total_bill'])
plt.show()

# %%
sns.distplot(df['total_bill'], hist=False)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

# %% [markdown]
# ### Visualizing statistical relationships

# %%
df = pd.read_csv(r"train_NIR5Yl1.csv")
df.head()
# Out:
#        ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0   52664   a      3942.0      2.0    155623   7855.0     42.0
# 1  327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2  468453   c      1358.0      4.0     56177   8067.0     60.0
# 3   96996   a       264.0      3.0    168793  27064.0      9.0
# 4  131465   c      4271.0      4.0    112223  13986.0     83.0

# %% [markdown]
# r stands for "raw" and will cause backslashes in the string to be interpreted as actual backslashes rather than special characters.

# %%
r'c:\path'
# Out:
# 'c:\\path'

# %%
r"hello\nworld"
# Out:
# 'hello\\nworld'

# %% [markdown]
# ### Scatter plot

# %%
sns.scatterplot(x='Views', y = 'Upvotes', data=df)
# Out:
# <AxesSubplot:xlabel='Views', ylabel='Upvotes'>

# %%
sns.relplot(x='Views', y = 'Upvotes', data=df)

# %% [markdown]
# #### Next, if we want to see the tag associated with the data

# %%
sns.relplot(x='Views', y = 'Upvotes',hue='Tag', data=df)

# %% [markdown]
# In the above plot, the hue semantic is categorical. That’s why it has a different color palette. If the hue semantic is numeric, then the coloring becomes sequential.

# %%
sns.relplot(x='Views', y = 'Upvotes',hue='Answers', data=df)

# %% [markdown]
# We can also change the size of each point:

# %%
sns.relplot(x='Views', y = 'Upvotes',size='Tag', data=df);

# %% [markdown]
# We can also change the size manually by using another parameter sizes as sizes = (15, 200).

# %% [markdown]
# ### Plotting categorical data

# %% [markdown]
# - Jitter
# - Hue
# - Boxplot
# - Voilion plot
# - pointplot

# %% [markdown]
# ### Jitter plot

# %%
df2 = pd.read_csv(r"train_LZdllcl.csv")
df2.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
sns.catplot(x = 'education', y='avg_training_score', data=df2)

# %% [markdown]
# Since we can see that the plot is scattered, so to handle that, we can set the jitter to false. Jitter is the deviation from the true value. So, we’ll set the jitter to false by using another parameter.

# %%
sns.catplot(x = 'education', y='avg_training_score', data=df2, jitter = False)

# %% [markdown]
# ### Hue plot

# %%
sns.catplot(x = 'education', y='avg_training_score',hue='gender', data=df2)

# %% [markdown]
# In the above plots, we can see that the points are overlapping each other, to eliminate this situation, we can set kind = “swarm”, swarm uses an algorithm that prevents the points from overlapping and adjusts the points along the categorical axis. Let’s see how it looks like-

# %%
#sns.catplot(x = 'education', y='avg_training_score',kind='swarm', data=df2)

# %% [markdown]
# Pretty amazing, right? What if we want to see the swarmed version of the plot as well as a third dimension? Let’s see how it goes if we introduce is_promoted as a new variable

# %%
# sns.catplot(x = 'education', y='avg_training_score',
#             hue = "is_promoted",
#             kind='swarm', data=df2)

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x='education', y = 'avg_training_score', data=df2)
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.catplot(x = 'education', y='avg_training_score',kind='box', data=df2)

# %%
sns.catplot(x = 'education', y='avg_training_score',kind='box',
            hue='is_promoted', data=df2)

# %% [markdown]
# ### Violin plot

# %%
sns.catplot(x='education', y = 'avg_training_score', hue='is_promoted',
           kind = 'violin', data=df2)

# %% [markdown]
# The violin plots combine the boxplot and kernel density estimation procedure to provide richer description of the distribution of values. The quartile values are displayed inside the violin. We can also split the violin when the hue semantic parameter has only two levels, which could also be helpful in saving space on the plot. Let’s look at the violin plot with a split of levels.

# %%
sns.catplot(x = 'education', y = 'avg_training_score',
           hue = 'is_promoted', kind='violin', split=True, data=df2)

# %% [markdown]
# ### Bar plot

# %%
sns.barplot(x = 'education', y = 'avg_training_score', data=df2)
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.barplot(x = 'education', y = 'avg_training_score',hue='is_promoted',
            data=df2)
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.catplot(x='education', y='avg_training_score', kind='bar', data=df2)

# %%
sns.catplot(x='education', y='avg_training_score',hue='is_promoted', kind='bar', data=df2)

# %% [markdown]
# ### Pointplot
#
# Another type of plot coming in is pointplot, and this plot points out the estimate value and confidence interval. Pointplot connects data from the same hue category. This helps in identifying how the relationship is changing in a particular hue category. You can check out how does a pointplot displays the information below.

# %%
sns.catplot(x='education', y='avg_training_score', hue='is_promoted',
           kind='point', data=df2)

# %% [markdown]
# ### Histogram

# %%
df.head()
# Out:
#        ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0   52664   a      3942.0      2.0    155623   7855.0     42.0
# 1  327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2  468453   c      1358.0      4.0     56177   8067.0     60.0
# 3   96996   a       264.0      3.0    168793  27064.0      9.0
# 4  131465   c      4271.0      4.0    112223  13986.0     83.0

# %%
sns.distplot(df2.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(df2.age, kde=False, rug=True)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ### Plotting Bivariate Distributions

# %% [markdown]
# - Hexplot
# - KDE plot
# - Boxen plot
# - Ridge plot

# %%
sns.jointplot(x = 'avg_training_score', y='age', data=df2)

# %% [markdown]
# ### Hexplot

# %%
sns.jointplot(x=df2.age, y=df2.avg_training_score, kind="hex", data=df2)

# %% [markdown]
# ### KDE plot

# %%
sns.jointplot(x=df2.age, y=df2.avg_training_score, kind="kde")

# %% [markdown]
# ### Heatmap

# %%
corrmat = df2.corr()

f, ax = plt.subplots(figsize = (9, 6))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Boxen plot

# %%
sns.catplot(x='age', y='avg_training_score', data=df2, kind="boxen", 
           height=4, aspect=2.7, hue="is_promoted")

# %% [markdown]
# ### pair plot

# %%
sns.pairplot(df2)
